# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df[['Age','Fare']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[['Age']]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Sex.mode().iloc[0]
# Out:
# 'male'

# %%
import numpy as np

# %%
a = np.array([True,True,True,False])

# %%
a.sum()
# Out:
# 3

# %%
(df.Sex == 'male').sum()
# Out:
# 577

# %%
(df.Sex == 'female').sum()
# Out:
# 314

# %%
True and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True and True
# Out:
# True

# %%
((df.Sex == 'male') & (df.Age > 35)).sum()
# Out:
# 144

# %%
((df.Sex == 'female') & (df.Age >= 35)& (df.Age <= 70)).sum()
# Out:
# 81

# %%
df.Survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
((df.Sex == 'male') & (df.Survived)).sum()
# Out:
# 109

# %%
((df.Sex == 'female') & (df.Survived)).sum()
# Out:
# 233

# %%
((df.Survived == 1)&(df.Sex == 'male')).sum()
# Out:
# 109

# %%
((df.Survived == 0)&(df.Sex == 'male')).sum()
# Out:
# 468

# %%
((df.Survived == 1)&(df.Sex == 'female')).sum()
# Out:
# 233

# %%
((df.Survived == 0)&(df.Sex == 'female')).sum()
# Out:
# 81

# %%
survived_male = ((df.Sex == 'male')&(df.Survived == 1)).sum()

# %%
survived_male
# Out:
# 109

# %%
total_male = (df.Sex == 'male').sum()

# %%
total_male
# Out:
# 577

# %%
survived_male/total_male * 100
# Out:
# 18.890814558058924

# %%
total_female = (df.Sex == 'female').sum()

# %%
total_female
# Out:
# 314

# %%
survived_female = ((df.Sex == 'female')&(df.Survived == 1)).sum()

# %%
survived_female
# Out:
# 233

# %%
survived_female/total_female * 100
# Out:
# 74.20382165605095
